# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("data/2019.csv")

print("cols: {}\nsize: {}x{}".format(list(df.columns), len(df.columns), df.size))
df.head()
# Out:
# cols: ['Rk', 'Player', 'Tm', 'FantPos', 'Age', 'G', 'GS', 'Cmp', 'Att', 'Yds', 'TD', 'Int', 'Att.1', 'Yds.1', 'Y/A', 'TD.1', 'Tgt', 'Rec', 'Yds.2', 'Y/R', 'TD.2', 'Fmb', 'FL', 'TD.3', '2PM', '2PP', 'FantPt', 'PPR', 'DKPt', 'FDPt', 'VBD', 'PosRank', 'OvRank']
# size: 33x19899
#    Rk                         Player   Tm FantPos  Age   G  GS  Cmp  Att  \
# 0   1  Christian McCaffrey*\McCaCh01  CAR      RB   23  16  16    0    2
# 1   2        Lamar Jackson*\JackLa00  BAL      QB   22  15  15  265  401
# 2   3        Derrick Henry*\HenrDe00  TEN      RB   25  15  15    0    0
# 3   4           Aaron Jones\JoneAa00  GNB      RB   25  16  16    0    0
# 4   5      Ezekiel Elliott*\ElliEz00  DAL      RB   24  16  16    0    0
#
#     Yds  ...  TD.3  2PM  2PP  FantPt    PPR   DKPt   FDPt    VBD  PosRank  \
# 0     0  ...    19  1.0  NaN   355.0  471.2  477.2  413.2  215.0        1
# 1  3127  ...     7  NaN  1.0   418.0  417.7  431.7  423.7  152.0        1
# ...

# %%
#TODO: column documentation on original data
#TODO: select which columns should be dropped and which should be used for analysis
df.drop(['Rk', '2PM', '2PP', 'FantPt', 'DKPt', 'FDPt', 'VBD', 'PosRank', 'OvRank', 'PPR', 'Fmb', 'GS'], axis=1, inplace=True)

# %%
#fix name formatting.
#Used lambda because its the only time it will be used. 
#Used 2 splits because '*' AND '\' are not always present in the string
df['Player'] = df['Player'].apply(lambda x: x.split('*')[0]).apply(lambda x: x.split('\\')[0])
#test for above lambda
print("Pass: {}".format(not bool([s for s in df['Player'] if ('*' in s) or ('\\' in s)])))
# Out:
# Pass: True
